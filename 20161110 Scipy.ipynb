# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\gcwee'

# %%
os.chdir("C:\\Users\\gcwee\\Documents\\HUST\\课程\\python\\files")

# %%
import os
os.chdir("C:\\Users\\gcwee\\Documents\\HUST\\课程\\python\\files")
os.getcwd()
# Out:
# 'C:\\Users\\gcwee\\Documents\\HUST\\课程\\python\\files'

# %%
import numpy as np
np.random.beta(5, 5, size=3)
# Out:
# array([ 0.5614125 ,  0.27209393,  0.6583868 ])

# %%
import numpy as np
from scipy.stats import beta
import matplotlib.pyplot as plt

q = beta(5, 5)      # Beta(a, b), with a = b = 5
obs = q.rvs(2000)   # 2000 observations
grid = np.linspace(0.01, 0.99, 100)

fig, ax = plt.subplots()
ax.hist(obs, bins=40, normed=True)
ax.plot(grid, q.pdf(grid), 'k-', linewidth=2)
plt.show()

# %%
q.cdf(0.4) #
# Out:
# 0.26656768000000003

# %%
q.pdf(0.4)
# Out:
# 2.0901888000000013

# %% [markdown]
#     consider the relationship between x and y is y=sin(4*(x-.25))+x+x**20-1

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
x=np.linspace(0,1,100)
y=np.sin(4*(x-1/4))+x+x**20-1

fig,ax=plt.subplots()
ax.plot(x,y,'b-',linewidth=2)
ax.plot(x,0*x,'k--')
ax.plot(0*x,y,'k--')
plt.show()

# %% [markdown]
#     unique root is about 0.408

# %% [markdown]
# bisection

# %%
def bisect(f, a, b, tol=10e-5):
    """
    Implements the bisection root finding algorithm, assuming that f is a
    real-valued function on [a, b] satisfying f(a) < 0 < f(b).
    """
    lower, upper = a, b

    while upper - lower > tol:
        middle = 0.5 * (upper + lower)
        # === if root is between lower and middle === #
        if f(middle) > 0:  
            lower, upper = lower, middle
        # === if root is between middle and upper  === #
        else:              
            lower, upper = middle, upper

    return 0.5 * (upper + lower)

# %%
import numpy as np
from scipy.optimize import bisect
f=lambda x : np.sin(4*(x-0.25))+x+x**20-1
bisect(f,0,1)
# Out:
# 0.4082935042806639

# %%
from scipy.optimize import bisect
f = lambda x: np.sin(4 * (x - 0.25)) + x + x**20 - 1
bisect(f, 0, 1)
# Out:
# 0.4082935042806639

# %%
from scipy.optimize import newton
newton(f,0.2)
# Out:
# 0.40829350427935679

# %%
newton(f,0.7)
# Out:
# 0.70017000000002816

# %%
bisect(f,0,0.5)
# Out:
# 0.4082935042806639

# %%
from scipy.optimize import brentq
brentq(f,0,1)
# Out:
# 0.40829350427936706

# %%
from scipy.optimize import fixed_point
fixed_point(lambda x:x**2,10)
# Out:
# array(1.0)

# %%
from scipy.optimize import fminbound
fminbound(lambda x:(x-2)**2,-1,2)
# Out:
# 1.9999965324591422

# %%
from scipy.integrate import quad
integral, error = quad(lambda x: x**2, 0, 1)
integral
# Out:
# 0.33333333333333337
